# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
import numpy as np
import os
#from scipy.misc import imread, imresize
import imageio
import datetime
import os
from skimage.io import imread
import cv2

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.random.set_seed(30)

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open('E:/Project_data/Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('E:/Project_data/Project_data/val.csv').readlines())
batch_size = 50

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
def generator(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx = [0,1,2,3,6,8,10,12,14,16,18,20,24,26,27,28,29]#create a list of image numbers you want to use for a particular video
    while True:
        t = np.random.permutation(folder_list)
        num_batches = int(len(folder_list)/batch_size)
        # calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            x=len(img_idx)
            #batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_data = np.zeros((batch_size,x,100,100,3))
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    height, width, channel = image.shape
                    if height == 120 and width == 120:
                        image = image[20:140, :120, :]
                    image = cv2.resize(image, (100, 100)) #resizing all image to 100*100
                    image = image/255

                    batch_data[folder,idx,:,:,0] = image[:,:,0]
                    #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = image[:,:,1]
                    #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = image[:,:,2]
                    #normalise and feed in the image

                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        # write the code for the remaining data points which are left after full batches
        if len(folder_list) > num_batches * batch_size:
            x=len(img_idx)
            rem = len(folder_list) - (num_batches * batch_size)
            batch_data = np.zeros((rem,x,100,100,3))
            batch_labels = np.zeros((rem,5)) # batch_labels is the one hot representation of the output
            for folder in range(rem): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (num_batches * batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (num_batches * batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    height, width , channel = image.shape
                    if height == 120 or width == 120:
                        image=image[20:140,:120,:]
                    image = cv2.resize(image,(100,100))
                    image = image/255
                    batch_data[folder,idx,:,:,0] = image[:,:,0]
                    #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = image[:,:,1]
                    #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = image[:,:,2]
                    #normalise and feed in the image

                batch_labels[folder, int(t[folder + (num_batches * batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = 'E:/Project_data/Project_data/train'
val_path = 'E:/Project_data/Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 50
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 50

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential
from keras.layers import Conv3D, MaxPooling3D, Flatten, Dense, Dropout
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

model = Sequential()

# 1st convolutional layer
model.add(Conv3D(16, kernel_size=(3,3,3), input_shape=(16,100,100,3), padding='same', activation='relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

# 2nd convolutional layer
model.add(Conv3D(32, kernel_size=(3,3,3), padding='same', activation='relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

# 3rd convolutional layer
model.add(Conv3D(64, kernel_size=(3,3,3), padding='same', activation='relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

# Flatten the output of the convolutional layers
model.add(Flatten())

# Add fully connected layers with dropout
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

# Output layer with softmax activation
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = 'SGD'
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_56 (Conv3D)          (None, 16, 100, 100, 16)  1312
#
#  max_pooling3d_44 (MaxPoolin  (None, 8, 50, 50, 16)    0
#  g3D)
#
#  conv3d_57 (Conv3D)          (None, 8, 50, 50, 32)     13856
#
#  max_pooling3d_45 (MaxPoolin  (None, 4, 25, 25, 32)    0
#  g3D)
#
#  conv3d_58 (Conv3D)          (None, 4, 25, 25, 64)     55360
#
#  max_pooling3d_46 (MaxPoolin  (None, 2, 12, 12, 64)    0
#  g3D)
#
#  flatten_12 (Flatten)        (None, 18432)             0
#
#  dense_26 (Dense)            (None, 256)               4718848
#
#  dropout_24 (Dropout)        (None, 256)               0
#
#  dense_27 (Dense)            (None, 128)               32896
#
#  dropout_25 (Dropout)        (None, 128)               0
#
#  dense_28 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 4,822,917
# Trainable params: 4,822,917
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001)
callbacks_list = [checkpoint, LR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\2\ipykernel_9884\1787904139.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
# Source path =  E:/Project_data/Project_data/train ; batch size = 50
# Epoch 1/50
# 14/14 [==============================] - ETA: 0s - loss: 1.6217 - categorical_accuracy: 0.2142 Source path =  E:/Project_data/Project_data/val ; batch size = 50
#
# Epoch 1: saving model to model_init_2023-02-1408_06_14.226787\model-00001-1.62166-0.21418-1.59495-0.29000.h5
# 14/14 [==============================] - 417s 30s/step - loss: 1.6217 - categorical_accuracy: 0.2142 - val_loss: 1.5950 - val_categorical_accuracy: 0.2900 - lr: 0.0100
# Epoch 2/50
# 14/14 [==============================] - ETA: 0s - loss: 1.6102 - categorical_accuracy: 0.2217
# Epoch 2: saving model to model_init_2023-02-1408_06_14.226787\model-00002-1.61016-0.22172-1.59387-0.25000.h5
# 14/14 [==============================] - 394s 28s/step - loss: 1.6102 - categorical_accuracy: 0.2217 - val_loss: 1.5939 - val_categorical_accuracy: 0.2500 - lr: 0.0100
# Epoch 3/50
# 14/14 [==============================] - ETA: 0s - loss: 1.6029 - categorical_accuracy: 0.2278
# Epoch 3: saving model to model_init_2023-02-1408_06_14.226787\model-00003-1.60288-0.22775-1.58552-0.31000.h5
# 14/14 [==============================] - 432s 31s/step - loss: 1.6029 - categorical_accuracy: 0.2278 - val_loss: 1.5855 - val_categorical_accuracy: 0.3100 - lr: 0.0100
# Epoch 4/50
# 14/14 [==============================] - ETA: 0s - loss: 1.5889 - categorical_accuracy: 0.2428
# Epoch 4: saving model to model_init_2023-02-1408_06_14.226787\model-00004-1.58888-0.24284-1.56290-0.24000.h5
# 14/14 [==============================] - 460s 33s/step - loss: 1.5889 - categorical_accuracy: 0.2428 - val_loss: 1.5629 - val_categorical_accuracy: 0.2400 - lr: 0.0100
# Epoch 5/50
# 14/14 [==============================] - ETA: 0s - loss: 1.5890 - categorical_accuracy: 0.2519
# Epoch 5: saving model to model_init_2023-02-1408_06_14.226787\model-00005-1.58902-0.25189-1.57050-0.26000.h5
# 14/14 [==============================] - 461s 33s/step - loss: 1.5890 - categorical_accuracy: 0.2519 - val_loss: 1.5705 - val_categorical_accuracy: 0.2600 - lr: 0.0100
# Epoch 6/50
# 14/14 [==============================] - ETA: 0s - loss: 1.5871 - categorical_accuracy: 0.2519
# Epoch 6: saving model to model_init_2023-02-1408_06_14.226787\model-00006-1.58705-0.25189-1.56045-0.37000.h5
# 14/14 [==============================] - 459s 33s/step - loss: 1.5871 - categorical_accuracy: 0.2519 - val_loss: 1.5604 - val_categorical_accuracy: 0.3700 - lr: 0.0100
# Epoch 7/50
# 14/14 [==============================] - ETA: 0s - loss: 1.5792 - categorical_accuracy: 0.2775
# Epoch 7: saving model to model_init_2023-02-1408_06_14.226787\model-00007-1.57916-0.27753-1.56760-0.37000.h5
# 14/14 [==============================] - 461s 33s/step - loss: 1.5792 - categorical_accuracy: 0.2775 - val_loss: 1.5676 - val_categorical_accuracy: 0.3700 - lr: 0.0100
# Epoch 8/50
# 14/14 [==============================] - ETA: 0s - loss: 1.5651 - categorical_accuracy: 0.2881
# Epoch 8: saving model to model_init_2023-02-1408_06_14.226787\model-00008-1.56512-0.28808-1.55576-0.51000.h5
# 14/14 [==============================] - 476s 34s/step - loss: 1.5651 - categorical_accuracy: 0.2881 - val_loss: 1.5558 - val_categorical_accuracy: 0.5100 - lr: 0.0100
# Epoch 9/50
# 14/14 [==============================] - ETA: 0s - loss: 1.5688 - categorical_accuracy: 0.2941
# Epoch 9: saving model to model_init_2023-02-1408_06_14.226787\model-00009-1.56884-0.29412-1.54129-0.32000.h5
# 14/14 [==============================] - 466s 33s/step - loss: 1.5688 - categorical_accuracy: 0.2941 - val_loss: 1.5413 - val_categorical_accuracy: 0.3200 - lr: 0.0100
# Epoch 10/50
# 14/14 [==============================] - ETA: 0s - loss: 1.5490 - categorical_accuracy: 0.3092
# Epoch 10: saving model to model_init_2023-02-1408_06_14.226787\model-00010-1.54901-0.30920-1.53245-0.44000.h5
# 14/14 [==============================] - 461s 33s/step - loss: 1.5490 - categorical_accuracy: 0.3092 - val_loss: 1.5325 - val_categorical_accuracy: 0.4400 - lr: 0.0100
# Epoch 11/50
# 14/14 [==============================] - ETA: 0s - loss: 1.5320 - categorical_accuracy: 0.3077
# Epoch 11: saving model to model_init_2023-02-1408_06_14.226787\model-00011-1.53198-0.30769-1.50595-0.49000.h5
# 14/14 [==============================] - 467s 33s/step - loss: 1.5320 - categorical_accuracy: 0.3077 - val_loss: 1.5059 - val_categorical_accuracy: 0.4900 - lr: 0.0100
# Epoch 12/50
# 14/14 [==============================] - ETA: 0s - loss: 1.5109 - categorical_accuracy: 0.3469
# Epoch 12: saving model to model_init_2023-02-1408_06_14.226787\model-00012-1.51090-0.34691-1.51369-0.38000.h5
# 14/14 [==============================] - 468s 33s/step - loss: 1.5109 - categorical_accuracy: 0.3469 - val_loss: 1.5137 - val_categorical_accuracy: 0.3800 - lr: 0.0100
# Epoch 13/50
# 14/14 [==============================] - ETA: 0s - loss: 1.5002 - categorical_accuracy: 0.3454
# Epoch 13: saving model to model_init_2023-02-1408_06_14.226787\model-00013-1.50022-0.34540-1.52150-0.40000.h5
# 14/14 [==============================] - 469s 34s/step - loss: 1.5002 - categorical_accuracy: 0.3454 - val_loss: 1.5215 - val_categorical_accuracy: 0.4000 - lr: 0.0100
# Epoch 14/50
# 14/14 [==============================] - ETA: 0s - loss: 1.5044 - categorical_accuracy: 0.3394
# Epoch 14: saving model to model_init_2023-02-1408_06_14.226787\model-00014-1.50442-0.33937-1.42678-0.51000.h5
# 14/14 [==============================] - 467s 33s/step - loss: 1.5044 - categorical_accuracy: 0.3394 - val_loss: 1.4268 - val_categorical_accuracy: 0.5100 - lr: 0.0100
# Epoch 15/50
# 14/14 [==============================] - ETA: 0s - loss: 1.4860 - categorical_accuracy: 0.3590
# Epoch 15: saving model to model_init_2023-02-1408_06_14.226787\model-00015-1.48597-0.35897-1.50634-0.31000.h5
# 14/14 [==============================] - 469s 33s/step - loss: 1.4860 - categorical_accuracy: 0.3590 - val_loss: 1.5063 - val_categorical_accuracy: 0.3100 - lr: 0.0100
# Epoch 16/50
# 14/14 [==============================] - ETA: 0s - loss: 1.4402 - categorical_accuracy: 0.4103
# Epoch 16: saving model to model_init_2023-02-1408_06_14.226787\model-00016-1.44024-0.41026-1.42330-0.43000.h5
# 14/14 [==============================] - 466s 33s/step - loss: 1.4402 - categorical_accuracy: 0.4103 - val_loss: 1.4233 - val_categorical_accuracy: 0.4300 - lr: 0.0100
# Epoch 17/50
# 14/14 [==============================] - ETA: 0s - loss: 1.4571 - categorical_accuracy: 0.3906
# Epoch 17: saving model to model_init_2023-02-1408_06_14.226787\model-00017-1.45706-0.39065-1.52425-0.36000.h5
# 14/14 [==============================] - 469s 33s/step - loss: 1.4571 - categorical_accuracy: 0.3906 - val_loss: 1.5243 - val_categorical_accuracy: 0.3600 - lr: 0.0100
# Epoch 18/50
# 14/14 [==============================] - ETA: 0s - loss: 1.4434 - categorical_accuracy: 0.3906
# Epoch 18: saving model to model_init_2023-02-1408_06_14.226787\model-00018-1.44341-0.39065-1.44541-0.42000.h5
# 14/14 [==============================] - 465s 33s/step - loss: 1.4434 - categorical_accuracy: 0.3906 - val_loss: 1.4454 - val_categorical_accuracy: 0.4200 - lr: 0.0100
# Epoch 19/50
# 14/14 [==============================] - ETA: 0s - loss: 1.4024 - categorical_accuracy: 0.4344
# Epoch 19: saving model to model_init_2023-02-1408_06_14.226787\model-00019-1.40239-0.43439-1.39729-0.47000.h5
# 14/14 [==============================] - 459s 33s/step - loss: 1.4024 - categorical_accuracy: 0.4344 - val_loss: 1.3973 - val_categorical_accuracy: 0.4700 - lr: 0.0100
# Epoch 20/50
# 14/14 [==============================] - ETA: 0s - loss: 1.4170 - categorical_accuracy: 0.4268
# Epoch 20: saving model to model_init_2023-02-1408_06_14.226787\model-00020-1.41700-0.42685-1.35116-0.56000.h5
# 14/14 [==============================] - 461s 33s/step - loss: 1.4170 - categorical_accuracy: 0.4268 - val_loss: 1.3512 - val_categorical_accuracy: 0.5600 - lr: 0.0100
# Epoch 21/50
# 14/14 [==============================] - ETA: 0s - loss: 1.3547 - categorical_accuracy: 0.4525
# Epoch 21: saving model to model_init_2023-02-1408_06_14.226787\model-00021-1.35469-0.45249-1.32009-0.50000.h5
# 14/14 [==============================] - 449s 32s/step - loss: 1.3547 - categorical_accuracy: 0.4525 - val_loss: 1.3201 - val_categorical_accuracy: 0.5000 - lr: 0.0100
# Epoch 22/50
# 14/14 [==============================] - ETA: 0s - loss: 1.3381 - categorical_accuracy: 0.4404
# Epoch 22: saving model to model_init_2023-02-1408_06_14.226787\model-00022-1.33813-0.44042-1.30443-0.45000.h5
# 14/14 [==============================] - 458s 32s/step - loss: 1.3381 - categorical_accuracy: 0.4404 - val_loss: 1.3044 - val_categorical_accuracy: 0.4500 - lr: 0.0100
# Epoch 23/50
# 14/14 [==============================] - ETA: 0s - loss: 1.3257 - categorical_accuracy: 0.4585
# Epoch 23: saving model to model_init_2023-02-1408_06_14.226787\model-00023-1.32568-0.45852-1.50103-0.33000.h5
# 14/14 [==============================] - 457s 33s/step - loss: 1.3257 - categorical_accuracy: 0.4585 - val_loss: 1.5010 - val_categorical_accuracy: 0.3300 - lr: 0.0100
# Epoch 24/50
# 14/14 [==============================] - ETA: 0s - loss: 1.3380 - categorical_accuracy: 0.4540
# Epoch 24: saving model to model_init_2023-02-1408_06_14.226787\model-00024-1.33802-0.45400-1.27931-0.48000.h5
# 14/14 [==============================] - 458s 33s/step - loss: 1.3380 - categorical_accuracy: 0.4540 - val_loss: 1.2793 - val_categorical_accuracy: 0.4800 - lr: 0.0100
# Epoch 25/50
# 14/14 [==============================] - ETA: 0s - loss: 1.2506 - categorical_accuracy: 0.5113
# Epoch 25: saving model to model_init_2023-02-1408_06_14.226787\model-00025-1.25057-0.51131-1.27242-0.50000.h5
# 14/14 [==============================] - 455s 32s/step - loss: 1.2506 - categorical_accuracy: 0.5113 - val_loss: 1.2724 - val_categorical_accuracy: 0.5000 - lr: 0.0100
# Epoch 26/50
# 14/14 [==============================] - ETA: 0s - loss: 1.2648 - categorical_accuracy: 0.5083
# Epoch 26: saving model to model_init_2023-02-1408_06_14.226787\model-00026-1.26483-0.50830-1.34308-0.51000.h5
# 14/14 [==============================] - 458s 33s/step - loss: 1.2648 - categorical_accuracy: 0.5083 - val_loss: 1.3431 - val_categorical_accuracy: 0.5100 - lr: 0.0100
# Epoch 27/50
# 14/14 [==============================] - ETA: 0s - loss: 1.2443 - categorical_accuracy: 0.4947
# Epoch 27: saving model to model_init_2023-02-1408_06_14.226787\model-00027-1.24431-0.49472-1.25192-0.53000.h5
# 14/14 [==============================] - 458s 33s/step - loss: 1.2443 - categorical_accuracy: 0.4947 - val_loss: 1.2519 - val_categorical_accuracy: 0.5300 - lr: 0.0100
# Epoch 28/50
# 14/14 [==============================] - ETA: 0s - loss: 1.2263 - categorical_accuracy: 0.5023
# Epoch 28: saving model to model_init_2023-02-1408_06_14.226787\model-00028-1.22635-0.50226-1.16152-0.52000.h5
# 14/14 [==============================] - 456s 33s/step - loss: 1.2263 - categorical_accuracy: 0.5023 - val_loss: 1.1615 - val_categorical_accuracy: 0.5200 - lr: 0.0100
# Epoch 29/50
# 14/14 [==============================] - ETA: 0s - loss: 1.1758 - categorical_accuracy: 0.5098
# Epoch 29: saving model to model_init_2023-02-1408_06_14.226787\model-00029-1.17582-0.50980-1.24061-0.58000.h5
# 14/14 [==============================] - 453s 32s/step - loss: 1.1758 - categorical_accuracy: 0.5098 - val_loss: 1.2406 - val_categorical_accuracy: 0.5800 - lr: 0.0100
# Epoch 30/50
# 14/14 [==============================] - ETA: 0s - loss: 1.1300 - categorical_accuracy: 0.5732
# Epoch 30: saving model to model_init_2023-02-1408_06_14.226787\model-00030-1.12996-0.57315-1.12392-0.63000.h5
# 14/14 [==============================] - 454s 32s/step - loss: 1.1300 - categorical_accuracy: 0.5732 - val_loss: 1.1239 - val_categorical_accuracy: 0.6300 - lr: 0.0100
# Epoch 31/50
# 14/14 [==============================] - ETA: 0s - loss: 1.0779 - categorical_accuracy: 0.5777
# Epoch 31: saving model to model_init_2023-02-1408_06_14.226787\model-00031-1.07792-0.57768-1.24461-0.44000.h5
# 14/14 [==============================] - 455s 32s/step - loss: 1.0779 - categorical_accuracy: 0.5777 - val_loss: 1.2446 - val_categorical_accuracy: 0.4400 - lr: 0.0100
# Epoch 32/50
# 14/14 [==============================] - ETA: 0s - loss: 1.1544 - categorical_accuracy: 0.5686
# Epoch 32: saving model to model_init_2023-02-1408_06_14.226787\model-00032-1.15439-0.56863-1.03313-0.56000.h5
# 14/14 [==============================] - 456s 32s/step - loss: 1.1544 - categorical_accuracy: 0.5686 - val_loss: 1.0331 - val_categorical_accuracy: 0.5600 - lr: 0.0100
# Epoch 33/50
# 14/14 [==============================] - ETA: 0s - loss: 1.0662 - categorical_accuracy: 0.5882
# Epoch 33: saving model to model_init_2023-02-1408_06_14.226787\model-00033-1.06622-0.58824-1.53577-0.36000.h5
# 14/14 [==============================] - 460s 33s/step - loss: 1.0662 - categorical_accuracy: 0.5882 - val_loss: 1.5358 - val_categorical_accuracy: 0.3600 - lr: 0.0100
# Epoch 34/50
# 14/14 [==============================] - ETA: 0s - loss: 1.0899 - categorical_accuracy: 0.5852
# Epoch 34: saving model to model_init_2023-02-1408_06_14.226787\model-00034-1.08992-0.58522-0.89249-0.70000.h5
# 14/14 [==============================] - 456s 32s/step - loss: 1.0899 - categorical_accuracy: 0.5852 - val_loss: 0.8925 - val_categorical_accuracy: 0.7000 - lr: 0.0100
# Epoch 35/50
# 14/14 [==============================] - ETA: 0s - loss: 0.9660 - categorical_accuracy: 0.6229
# Epoch 35: saving model to model_init_2023-02-1408_06_14.226787\model-00035-0.96603-0.62293-1.04387-0.61000.h5
# 14/14 [==============================] - 462s 33s/step - loss: 0.9660 - categorical_accuracy: 0.6229 - val_loss: 1.0439 - val_categorical_accuracy: 0.6100 - lr: 0.0100
# Epoch 36/50
# 14/14 [==============================] - ETA: 0s - loss: 0.9321 - categorical_accuracy: 0.6365
# Epoch 36: saving model to model_init_2023-02-1408_06_14.226787\model-00036-0.93208-0.63650-0.86598-0.70000.h5
# 14/14 [==============================] - 460s 33s/step - loss: 0.9321 - categorical_accuracy: 0.6365 - val_loss: 0.8660 - val_categorical_accuracy: 0.7000 - lr: 0.0100
# Epoch 37/50
# 14/14 [==============================] - ETA: 0s - loss: 0.8778 - categorical_accuracy: 0.6817
# Epoch 37: saving model to model_init_2023-02-1408_06_14.226787\model-00037-0.87781-0.68175-1.08849-0.58000.h5
# 14/14 [==============================] - 462s 33s/step - loss: 0.8778 - categorical_accuracy: 0.6817 - val_loss: 1.0885 - val_categorical_accuracy: 0.5800 - lr: 0.0100
# Epoch 38/50
# 14/14 [==============================] - ETA: 0s - loss: 0.8654 - categorical_accuracy: 0.6682
# Epoch 38: saving model to model_init_2023-02-1408_06_14.226787\model-00038-0.86535-0.66817-1.21084-0.58000.h5
# 14/14 [==============================] - 463s 33s/step - loss: 0.8654 - categorical_accuracy: 0.6682 - val_loss: 1.2108 - val_categorical_accuracy: 0.5800 - lr: 0.0100
# Epoch 39/50
# 14/14 [==============================] - ETA: 0s - loss: 0.8303 - categorical_accuracy: 0.6817
# Epoch 39: saving model to model_init_2023-02-1408_06_14.226787\model-00039-0.83030-0.68175-0.81929-0.72000.h5
# 14/14 [==============================] - 464s 33s/step - loss: 0.8303 - categorical_accuracy: 0.6817 - val_loss: 0.8193 - val_categorical_accuracy: 0.7200 - lr: 0.0100
# Epoch 40/50
# 14/14 [==============================] - ETA: 0s - loss: 0.7907 - categorical_accuracy: 0.7044
# Epoch 40: saving model to model_init_2023-02-1408_06_14.226787\model-00040-0.79070-0.70437-1.21887-0.54000.h5
# 14/14 [==============================] - 463s 33s/step - loss: 0.7907 - categorical_accuracy: 0.7044 - val_loss: 1.2189 - val_categorical_accuracy: 0.5400 - lr: 0.0100
# Epoch 41/50
# 14/14 [==============================] - ETA: 0s - loss: 0.8101 - categorical_accuracy: 0.7089
# Epoch 41: saving model to model_init_2023-02-1408_06_14.226787\model-00041-0.81014-0.70890-0.77620-0.71000.h5
# 14/14 [==============================] - 465s 33s/step - loss: 0.8101 - categorical_accuracy: 0.7089 - val_loss: 0.7762 - val_categorical_accuracy: 0.7100 - lr: 0.0100
# Epoch 42/50
# 14/14 [==============================] - ETA: 0s - loss: 0.7489 - categorical_accuracy: 0.7179
# Epoch 42: saving model to model_init_2023-02-1408_06_14.226787\model-00042-0.74888-0.71795-0.88843-0.67000.h5
# 14/14 [==============================] - 463s 33s/step - loss: 0.7489 - categorical_accuracy: 0.7179 - val_loss: 0.8884 - val_categorical_accuracy: 0.6700 - lr: 0.0100
# Epoch 43/50
# 14/14 [==============================] - ETA: 0s - loss: 0.7166 - categorical_accuracy: 0.7285
# Epoch 43: saving model to model_init_2023-02-1408_06_14.226787\model-00043-0.71657-0.72851-0.73030-0.72000.h5
# 14/14 [==============================] - 463s 33s/step - loss: 0.7166 - categorical_accuracy: 0.7285 - val_loss: 0.7303 - val_categorical_accuracy: 0.7200 - lr: 0.0100
# Epoch 44/50
# 14/14 [==============================] - ETA: 0s - loss: 0.6464 - categorical_accuracy: 0.7677
# Epoch 44: saving model to model_init_2023-02-1408_06_14.226787\model-00044-0.64643-0.76772-0.80065-0.69000.h5
# 14/14 [==============================] - 466s 33s/step - loss: 0.6464 - categorical_accuracy: 0.7677 - val_loss: 0.8006 - val_categorical_accuracy: 0.6900 - lr: 0.0100
# Epoch 45/50
# 14/14 [==============================] - ETA: 0s - loss: 0.6827 - categorical_accuracy: 0.7602
# Epoch 45: saving model to model_init_2023-02-1408_06_14.226787\model-00045-0.68273-0.76018-0.75538-0.72000.h5
# 14/14 [==============================] - 466s 33s/step - loss: 0.6827 - categorical_accuracy: 0.7602 - val_loss: 0.7554 - val_categorical_accuracy: 0.7200 - lr: 0.0100
# Epoch 46/50
# 14/14 [==============================] - ETA: 0s - loss: 0.6320 - categorical_accuracy: 0.7707
# Epoch 46: saving model to model_init_2023-02-1408_06_14.226787\model-00046-0.63202-0.77074-1.13467-0.59000.h5
# 14/14 [==============================] - 465s 33s/step - loss: 0.6320 - categorical_accuracy: 0.7707 - val_loss: 1.1347 - val_categorical_accuracy: 0.5900 - lr: 0.0100
# Epoch 47/50
# 14/14 [==============================] - ETA: 0s - loss: 0.7166 - categorical_accuracy: 0.7330
# Epoch 47: saving model to model_init_2023-02-1408_06_14.226787\model-00047-0.71657-0.73303-0.78048-0.73000.h5
# 14/14 [==============================] - 466s 33s/step - loss: 0.7166 - categorical_accuracy: 0.7330 - val_loss: 0.7805 - val_categorical_accuracy: 0.7300 - lr: 0.0100
# Epoch 48/50
# 14/14 [==============================] - ETA: 0s - loss: 0.6054 - categorical_accuracy: 0.7813
# Epoch 48: saving model to model_init_2023-02-1408_06_14.226787\model-00048-0.60540-0.78130-0.98720-0.64000.h5
# 14/14 [==============================] - 468s 33s/step - loss: 0.6054 - categorical_accuracy: 0.7813 - val_loss: 0.9872 - val_categorical_accuracy: 0.6400 - lr: 0.0100
# Epoch 49/50
# 14/14 [==============================] - ETA: 0s - loss: 0.5488 - categorical_accuracy: 0.7979
# Epoch 49: saving model to model_init_2023-02-1408_06_14.226787\model-00049-0.54880-0.79789-0.63173-0.77000.h5
# 14/14 [==============================] - 462s 33s/step - loss: 0.5488 - categorical_accuracy: 0.7979 - val_loss: 0.6317 - val_categorical_accuracy: 0.7700 - lr: 0.0020
# Epoch 50/50
# 14/14 [==============================] - ETA: 0s - loss: 0.5116 - categorical_accuracy: 0.8145
# Epoch 50: saving model to model_init_2023-02-1408_06_14.226787\model-00050-0.51156-0.81448-0.54264-0.81000.h5
# 14/14 [==============================] - 463s 33s/step - loss: 0.5116 - categorical_accuracy: 0.8145 - val_loss: 0.5426 - val_categorical_accuracy: 0.8100 - lr: 0.0020

# %%
model.save_weights("model_2.h5")

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
# Plot training & validation accuracy values
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
